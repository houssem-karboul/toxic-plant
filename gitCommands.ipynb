# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
cd gdrive/MyDrive/ToxicPlant
# Out:
# /content/gdrive/MyDrive/ToxicPlant

# %%
# !pwd
# Out:
# /content/gdrive/MyDrive/ToxicPlant

# %%
ls -la
# Out:
# total 49
# drwx------ 4 root root  4096 Feb 20 22:04 .git/
# -rw------- 1 root root  5986 Mar 24 19:08 gitCommands.ipynb
# -rw------- 1 root root 39397 Jan 28 20:19 toxic_plant.ipynb

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /content/gdrive/MyDrive/ToxicPlant/.git/

# %%
# !git remote add origin https://houssem-karboul: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@github.com/houssem-karboul/toxic-plant.git
# !git remote -v
# Out:
# fatal: remote origin already exists.
# origin	https://houssem-karboul:naruto6mx@github.com/houssem-karboul/toxic-plant.git (fetch)
# origin	https://houssem-karboul:naruto6mx@github.com/houssem-karboul/toxic-plant.git (push)

# %%
# !git config --global user.email '{mhkarbouldev@gmail.com}'
# !git config --global user.name '{houssem-karboul}'

# %%
# !git add .
# !git commit -m 'First commit'
# Out:
# [master 6d32a42] First commit
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite gitCommands.ipynb (85%)

# %%
# !git push origin master
# Out:
# remote: Support for password authentication was removed on August 13, 2021. Please use a personal access token instead.
# remote: Please see https://github.blog/2020-12-15-token-authentication-requirements-for-git-operations/ for more information.
# fatal: Authentication failed for 'https://houssem-karboul:naruto6mx@github.com/houssem-karboul/toxic-plant.git/'

# %%
# !git config --global --unset https.proxy
