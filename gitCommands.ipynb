# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
cd gdrive/MyDrive/ToxicPlant
# Out:
# /content/gdrive/MyDrive/ToxicPlant

# %%
# !pwd
# Out:
# /content/gdrive/MyDrive/ToxicPlant

# %%
ls -la
# Out:
# total 46
# drwx------ 2 root root  4096 Mar 24 19:31 .git/
# -rw------- 1 root root  5635 Mar 27 12:45 gitCommands.ipynb
# -rw------- 1 root root 35887 Mar 27 12:44 toxic_plant.ipynb

# %%
# !git init
# Out:
# Initialized empty Git repository in /content/gdrive/MyDrive/ToxicPlant/.git/

# %%
# !git remote add origin https://houssem-karboul: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@github.com/houssem-karboul/toxic-plant.git
# !git remote -v
# Out:
# origin	https://houssem-karboul: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@github.com/houssem-karboul/toxic-plant.git (fetch)
# origin	https://houssem-karboul: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@github.com/houssem-karboul/toxic-plant.git (push)

# %%
# !git config --global user.email '{mhkarbouldev@gmail.com}'
# !git config --global user.name '{houssem-karboul}'

# %%
# !git add . #Implement Artificial neurone,Train model !
# !git commit -m 'add test_plant percent to be toxic'
# Out:
# [master 3e60abb] add test_plant percent to be toxic
#  2 files changed, 2 insertions(+), 2 deletions(-)

# %%
# !git push origin master
# Out:
# Counting objects: 7, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (7/7), done.
# Writing objects: 100% (7/7), 1.35 KiB | 230.00 KiB/s, done.
# Total 7 (delta 3), reused 0 (delta 0)
# remote: Resolving deltas: 100% (3/3), completed with 2 local objects.
# To https://github.com/houssem-karboul/toxic-plant.git
#    c4ce4c5..f7a8599  master -> master

# %%
# !git reset --hard 8423577
# Out:
# HEAD is now at 8423577 First commit
